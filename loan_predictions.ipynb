# %%
from sklearn import preprocessing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#preprocessing part
x_train=np.genfromtxt('E:\data_sets\loan_prediction-1\X_train.csv',delimiter=',')
y_train=np.genfromtxt('E:\data_sets\loan_prediction-1\Y_train.csv',delimiter=',')
x_test=np.genfromtxt('E:\data_sets\loan_prediction-1\X_test.csv',delimiter=',')
y_test=np.genfromtxt('E:\data_sets\loan_prediction-1\Y_test.csv',delimiter=',')
x_trainp=pd.read_csv('E:\data_sets\loan_prediction-1\X_train.csv')
y_trainp=pd.read_csv('E:\data_sets\loan_prediction-1\Y_train.csv')
x_testp=pd.read_csv('E:\data_sets\loan_prediction-1\X_test.csv')
y_testp=pd.read_csv('E:\data_sets\loan_prediction-1\Y_test.csv')
print(x_trainp.head())
print(y_trainp.head())
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001032   Male      No          0  Graduate            No
# 1  LP001824   Male     Yes          1  Graduate            No
# 2  LP002928   Male     Yes          0  Graduate            No
# 3  LP001814   Male     Yes          2  Graduate            No
# 4  LP002244   Male     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4950                0.0         125               360
# 1             2882             1843.0         123               480
# 2             3000             3416.0          56               180
# 3             9703                0.0         112               360
# 4             2333             2417.0         136               360
#
#    Credit_History Property_Area
# 0               1         Urban
# 1               1     Semiurban
# 2               1     Semiurban
# 3               1         Urban
# ...

# %%
x_trainp.Gender=pd.Categorical(pd.factorize(x_trainp.Gender)[0])
x_trainp.Married=pd.Categorical(pd.factorize(x_trainp.Married)[0])
x_trainp.Education=pd.Categorical(pd.factorize(x_trainp.Education)[0])
x_trainp.Self_Employed=pd.Categorical(pd.factorize(x_trainp.Self_Employed)[0])
x_trainp.Property_Area=pd.Categorical(pd.factorize(x_trainp.Property_Area)[0])

# %%
del x_trainp['Loan_ID']
print(x_trainp.head())
# Out:
#   Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0      0       0          0         0             0             4950
# 1      0       1          1         0             0             2882
# 2      0       1          0         0             0             3000
# 3      0       1          2         0             0             9703
# 4      0       1          0         0             0             2333
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         125               360               1
# 1             1843.0         123               480               1
# 2             3416.0          56               180               1
# 3                0.0         112               360               1
# 4             2417.0         136               360               1
#
#   Property_Area
# 0             0
# 1             1
# 2             1
# 3             0
# 4             0

# %%
print(x_trainp.dtypes)
x_trainp[x_trainp.dtypes[(x_trainp.dtypes=="float64")|(x_trainp.dtypes=="int64")]
                        .index.values].hist(figsize=[11,11])
print('-----------------------------------')
# Out:
# Gender               category
# Married              category
# Dependents             object
# Education            category
# Self_Employed        category
# ApplicantIncome         int64
# CoapplicantIncome     float64
# LoanAmount              int64
# Loan_Amount_Term        int64
# Credit_History          int64
# Property_Area        category
# dtype: object
# -----------------------------------

# %%
x_scaled = preprocessing.scale(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-7e2ea8f1e656> in <module>()
# ----> 1 x_scaled = preprocessing.scale(x_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in scale(X, axis, with_mean, with_std, copy)
#     131     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     132                     warn_on_dtype=True, estimator='the scale function',
# --> 133                     dtype=FLOAT_DTYPES)
#     134     if sparse.issparse(X):
#     135         if with_mean:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# ...

# %%
# Out:
# -----------------------------

# %%
del x_trainp['Dependents']
x_scaled = preprocessing.scale(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-3b76457152fb> in <module>()
#       1 del x_trainp['Dependents']
# ----> 2 x_scaled = preprocessing.scale(x_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in scale(X, axis, with_mean, with_std, copy)
#     131     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     132                     warn_on_dtype=True, estimator='the scale function',
# --> 133                     dtype=FLOAT_DTYPES)
#     134     if sparse.issparse(X):
#     135         if with_mean:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
# ...
